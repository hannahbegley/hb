# %%
import pandas as pd
import numpy as np

# %%
"""this is what worked to create the existing file #read in SHARE json records and set encoding to utf-8
data = pd.read_json('UCSD_records.json', orient = 'columns', encoding="utf-8")"""


data = pd.read_json('UCSD_records.json', orient = 'columns')

# %%
#take a look at the data- this is only first-level broken out json (note the _source column still contains many fields)
data.head()
# Out:
#              _id             _index  _score  \
# 0  46243-B78-8F9  share_customtax_1     NaN
# 1  460D5-0F1-870  share_customtax_1     NaN
# 2  46065-8A1-338  share_customtax_1     NaN
# 3  460C4-C4F-337  share_customtax_1     NaN
# 4  461F6-6B8-F85  share_customtax_1     NaN
#
#                                              _source          _type  \
# 0  {u'contributors': [u'Bertrand Bellenot', u'Ani...  creativeworks
# 1  {u'contributors': [u'Anirudha Bose', u'marsupi...  creativeworks
# 2  {u'contributors': [u'S. H. Lee', u'S. C. Esene...  creativeworks
# 3  {u'contributors': [u'R. C. Puetter', u'Barbara...  creativeworks
# 4  {u'contributors': [u'Donald Rutherford'], u'da...  creativeworks
#
#               sort
# 0  [1505096181545]
# 1  [1505096180930]
# 2  [1505009985066]
# 3  [1505009809752]
# 4  [1505009201018]

# %%
##create a small subset of data for experimenting
# data[:10000].to_csv('testing_first10k.csv')

# %%
#_source contains plenty of other fields we'd like to examine on their own- so can do the same thing to expand that json, this time into index
expanded_data = pd.read_json( (data['_source']).to_json(), orient='index')

# %%
#review expanded data- note could further do the same thing for contributors, or affiliations
expanded_data.head()
# Out:
#                                            affiliations  \
# 0     [CERN, CERN, CERN, CERN, CERN, MPIK/CERN, CERN...
# 1     [CERN, CERN, GSI, LBL, UCSD, CERN, CERN, CERN,...
# 10    [Fudan University - The Fifth People's Hospita...
# 100                                                  []
# 1000  [Boehringer Ingelheim, University of Liverpool...
#
#                                            contributors                date  \
# 0     [Bertrand Bellenot, Anirudha Bose, Fons Radema... 2017-08-25 00:00:00
# 1     [Anirudha Bose, marsupial, Andrei Gheata, Stef... 2017-08-25 00:00:00
# 10    [Kun-Liang Guan, Yue Xiong, Minjia Tan, Yan Mo... 2017-09-08 17:06:44
# 100   [David A. Holway, John S. Ascher, Keng-Lou Jam... 2017-08-30 17:46:28
# 1000  [Ulrike Weyer-Czernilofsky, Michael Schmid, Ai... 2017-01-01 00:00:00
#
#                           date_created                     date_modified  \
# 0     2017-09-11T02:16:21.545767+00:00   2017-09-11T02:16:26.21514+00:00
# 1     2017-09-11T02:16:20.930481+00:00  2017-09-11T02:16:20.930452+00:00
# 10    2017-09-09T11:41:34.896519+00:00   2017-09-09T11:41:34.89649+00:00
# 100   2017-08-31T02:50:23.369779+00:00  2017-08-31T02:50:23.369725+00:00
# 1000   2017-07-24T02:43:38.33088+00:00   2017-07-25T02:43:18.13262+00:00
#
#                  date_published               date_updated  \
# 0     2017-08-25T00:00:00+00:00  2017-09-10T19:07:35+00:00
# 1     2017-08-25T00:00:00+00:00  2017-09-10T19:07:33+00:00
# 10                         None  2017-09-08T17:06:44+00:00
# 100                        None  2017-08-30T17:46:28+00:00
# 1000  2017-01-01T00:00:00+00:00  2017-07-23T00:00:00+00:00
#
#                                             description  \
# 0     Patch release of the v6-10 series. See https:/...
# 1     Patch release of the v6-10 series. See https:/...
# 10
# 100
# 1000  Breast cancer remains the leading cause of can...
#
#                                                 funders hosts    ...     \
# 0                                                   NaN   NaN    ...
# 1                                                   NaN   NaN    ...
# 10                                                  NaN   NaN    ...
# 100   [National Geographic Society, Sigma-Xi Society...   NaN    ...
# 1000                                                NaN   NaN    ...
#
#      registration_type retracted              sources subject_synonyms  \
# 0                 None         0       [DataCite MDS]               []
# 1                 None         0       [DataCite MDS]               []
# 10                None         0           [CrossRef]               []
# 100               None         0           [CrossRef]               []
# 1000              None         0  [bioRxiv, CrossRef]               []
#
#      subjects                                               tags  \
# 0          []                      [software, cern.zenodo, cern]
# 1          []                      [software, cern, cern.zenodo]
# 10         []    [cell biology, molecular biology, biochemistry]
# 100        []  [general medicine, general biochemistry, genet...
# 1000       []                                   [cancer biology]
#
#                                                   title      type  \
# 0     Root - An Object-Oriented Data Analysis Framew...  software
# 1     Root - An Object-Oriented Data Analysis Framew...  software
# 10    SIRT7 deacetylates DDB1 and suppresses the act...   article
# 100   Urbanization-induced habitat fragmentation ero...   article
# 1000  Blockade of insulin-like growth factors increa...  preprint
#
#                                        types withdrawn
# 0                  [software, creative work]       NaN
# 1                  [software, creative work]       NaN
# 10     [article, publication, creative work]       NaN
# 100    [article, publication, creative work]       NaN
# 1000  [preprint, publication, creative work]       NaN
#
# [5 rows x 26 columns]

# %%
# #just checking the 2 datasets are the same length- sanity check really
# print len(data)
# print len(expanded_data)
# Out:
# 18751
# 18751

# %%
#can put two datasets back together, and remove "_source" column (which was expanded into expanded_data)
combined_data = pd.concat([data, expanded_data], axis=1)
combined_data = combined_data.drop('_source', axis=1)

# %%
combined_data.head()
# Out:
#              _id             _index  _score          _type             sort  \
# 0  46243-B78-8F9  share_customtax_1     NaN  creativeworks  [1505096181545]
# 1  460D5-0F1-870  share_customtax_1     NaN  creativeworks  [1505096180930]
# 2  46065-8A1-338  share_customtax_1     NaN  creativeworks  [1505009985066]
# 3  460C4-C4F-337  share_customtax_1     NaN  creativeworks  [1505009809752]
# 4  461F6-6B8-F85  share_customtax_1     NaN  creativeworks  [1505009201018]
#
#                                         affiliations  \
# 0  [CERN, CERN, CERN, CERN, CERN, MPIK/CERN, CERN...
# 1  [CERN, CERN, GSI, LBL, UCSD, CERN, CERN, CERN,...
# 2  [University of California at San Diego (United...
# 3  [University of California (United States), Uni...
# 4  [Department of Philosophy, University of Calif...
#
#                                         contributors                date  \
# 0  [Bertrand Bellenot, Anirudha Bose, Fons Radema... 2017-08-25 00:00:00
# 1  [Anirudha Bose, marsupial, Andrei Gheata, Stef... 2017-08-25 00:00:00
# 2  [S. H. Lee, S. C. Esener, T. J. Drabik, M. A. ... 2017-09-09 19:30:32
# 3  [R. C. Puetter, Barbara Jones, Scott D. Friedman] 2017-09-09 13:41:12
# 4                                [Donald Rutherford] 2017-09-09 06:46:18
#
#                        date_created                     date_modified  \
# 0  2017-09-11T02:16:21.545767+00:00   2017-09-11T02:16:26.21514+00:00
# 1  2017-09-11T02:16:20.930481+00:00  2017-09-11T02:16:20.930452+00:00
# 2  2017-09-10T02:19:45.066231+00:00  2017-09-10T02:19:45.066215+00:00
# 3  2017-09-10T02:16:49.752745+00:00  2017-09-10T02:16:49.752713+00:00
# 4  2017-09-10T02:06:41.018803+00:00  2017-09-10T02:06:41.018787+00:00
#
#      ...    registration_type retracted         sources subject_synonyms  \
# 0    ...                 None         0  [DataCite MDS]               []
# 1    ...                 None         0  [DataCite MDS]               []
# 2    ...                 None         0      [CrossRef]               []
# 3    ...                 None         0      [CrossRef]               []
# 4    ...                 None         0      [CrossRef]               []
#
#   subjects                           tags  \
# 0       []  [software, cern.zenodo, cern]
# 1       []  [software, cern, cern.zenodo]
# 2       []                             []
# 3       []                             []
# 4       []                [health policy]
#
#                                                title              type  \
# 0  Root - An Object-Oriented Data Analysis Framew...          software
# 1  Root - An Object-Oriented Data Analysis Framew...          software
# 2  One-Dimensional Silicon/PLZT Spatial Light Mod...  conference paper
# 3  The University of California at San Diego Near...  conference paper
# 4                         Nietzsche as perfectionist           article
#
#                                             types withdrawn
# 0                       [software, creative work]       NaN
# 1                       [software, creative work]       NaN
# 2  [conference paper, publication, creative work]       NaN
# 3  [conference paper, publication, creative work]       NaN
# 4           [article, publication, creative work]       NaN
#
# [5 rows x 31 columns]

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18751 entries, 0 to 18750
# Data columns (total 31 columns):
# _id                  18751 non-null object
# _index               18751 non-null object
# _score               0 non-null float64
# _type                18751 non-null object
# sort                 18751 non-null object
# affiliations         18124 non-null object
# contributors         18124 non-null object
# date                 18751 non-null datetime64[ns]
# date_created         18751 non-null object
# date_modified        18751 non-null object
# date_published       4689 non-null object
# date_updated         14231 non-null object
# description          18751 non-null object
# funders              9351 non-null object
# hosts                97 non-null object
# id                   18751 non-null object
# identifiers          18751 non-null object
# justification        0 non-null float64
# language             3696 non-null object
# lists                18751 non-null object
# publishers           10482 non-null object
# registration_type    4 non-null object
# retracted            18751 non-null int64
# sources              18751 non-null object
# subject_synonyms     18751 non-null object
# subjects             18751 non-null object
# tags                 18751 non-null object
# title                18751 non-null object
# type                 18751 non-null object
# types                18751 non-null object
# withdrawn            4 non-null float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(26)
# memory usage: 4.6+ MB

# %%
##select whether you want excel or csv
combined_data.to_excel('SHARE-UCSD-export_reformatted.xlsx',encoding="utf-8", index=False)
combined_data.to_csv('SHARE-UCSD-export_reformatted.csv',encoding="utf-8", index=False)

# %%
# testing = pd.read_excel('SHARE-UCSD-export_reformatted.xlsx')
testing = pd.read_csv('SHARE-UCSD-export_reformatted.csv')

# %%
#review saved data
testing.head()
# Out:
#              _id             _index  _score          _type             sort  \
# 0  46243-B78-8F9  share_customtax_1     NaN  creativeworks  [1505096181545]
# 1  460D5-0F1-870  share_customtax_1     NaN  creativeworks  [1505096180930]
# 2  46065-8A1-338  share_customtax_1     NaN  creativeworks  [1505009985066]
# 3  460C4-C4F-337  share_customtax_1     NaN  creativeworks  [1505009809752]
# 4  461F6-6B8-F85  share_customtax_1     NaN  creativeworks  [1505009201018]
#
#                                         affiliations  \
# 0  [CERN, CERN, CERN, CERN, CERN, MPIK/CERN, CERN...
# 1  [CERN, CERN, GSI, LBL, UCSD, CERN, CERN, CERN,...
# 2  [University of California at San Diego (United...
# 3  [University of California (United States), Uni...
# 4  [Department of Philosophy, University of Calif...
#
#                                         contributors  \
# 0  [Bertrand Bellenot, Anirudha Bose, Fons Radema...
# 1  [Anirudha Bose, marsupial, Andrei Gheata, Stef...
# 2  [S. H. Lee, S. C. Esener, T. J. Drabik, M. A. ...
# 3  [R. C. Puetter, Barbara Jones, Scott D. Friedman]
# 4                                [Donald Rutherford]
#
#                          date                      date_created  \
# 0  2017-08-25 00:00:00.000000  2017-09-11T02:16:21.545767+00:00
# 1  2017-08-25 00:00:00.000000  2017-09-11T02:16:20.930481+00:00
# 2  2017-09-09 19:30:32.000000  2017-09-10T02:19:45.066231+00:00
# 3  2017-09-09 13:41:12.000000  2017-09-10T02:16:49.752745+00:00
# 4  2017-09-09 06:46:18.000000  2017-09-10T02:06:41.018803+00:00
#
#                       date_modified    ...    registration_type retracted  \
# 0   2017-09-11T02:16:26.21514+00:00    ...                  NaN         0
# 1  2017-09-11T02:16:20.930452+00:00    ...                  NaN         0
# 2  2017-09-10T02:19:45.066215+00:00    ...                  NaN         0
# 3  2017-09-10T02:16:49.752713+00:00    ...                  NaN         0
# 4  2017-09-10T02:06:41.018787+00:00    ...                  NaN         0
#
#           sources subject_synonyms subjects                           tags  \
# 0  [DataCite MDS]               []       []  [software, cern.zenodo, cern]
# 1  [DataCite MDS]               []       []  [software, cern, cern.zenodo]
# 2      [CrossRef]               []       []                             []
# 3      [CrossRef]               []       []                             []
# 4      [CrossRef]               []       []                [health policy]
#
#                                                title              type  \
# 0  Root - An Object-Oriented Data Analysis Framew...          software
# 1  Root - An Object-Oriented Data Analysis Framew...          software
# 2  One-Dimensional Silicon/PLZT Spatial Light Mod...  conference paper
# 3  The University of California at San Diego Near...  conference paper
# 4                         Nietzsche as perfectionist           article
#
#                                             types withdrawn
# 0                       [software, creative work]       NaN
# 1                       [software, creative work]       NaN
# 2  [conference paper, publication, creative work]       NaN
# 3  [conference paper, publication, creative work]       NaN
# 4           [article, publication, creative work]       NaN
#
# [5 rows x 31 columns]

# %%
print testing['affiliations'][:1]
print type(testing['affiliations'])
# Out:
# 0    [CERN, CERN, CERN, CERN, CERN, MPIK/CERN, CERN...
# Name: affiliations, dtype: object
# <class 'pandas.core.series.Series'>

# %%
"""code to remove duplicates from remaining lists in data"""
"""set a list of columns to loop through and de-dup and initialize a counter to loop through the list of columns"""
de_dup_list = ["affiliations", "contributors", "publishers", "tags"]
s = 0

while s < len(de_dup_list):
    """select a column from the de_dup_list of columns"""
    selected_column = de_dup_list[s]
    print selected_column 
    """to confirm selected column"""
    """set counter for row within that column"""
    i = 0
    """set new_col to a blank column- this is where de-duped row values will be appended"""
    new_col = []
    
    while i < len(testing[selected_column]):
#     while i < 10:
        #fill in blank cells so won't throw error
        testing[selected_column] = testing[selected_column].fillna("[]")
        """select a single row"""
        row = testing[selected_column][i]    
        row = [str(x) for x in row.split(',')]  
    #     print "original values:", row, len(row)
        new_list = []
        for item in row:
            """remove lingering json list formatting and convert unique values into list-
            this is instead of translating the json list into a dataframe as done above"""
            item = item.strip("[").strip("]").strip() 
            if item not in new_list:
                new_list.append(item)
            new_list = list(set(new_list))
        new_col.append(new_list)
    #     print "de-duplicated values: ", new_list, len(new_list)
        i += 1
        """assign cleaned up values to original dataframe """
    print len(new_col)
    testing[selected_column] = new_col
#         print new_col
    s +=1
# Out:
# affiliations
# 18751
# contributors
# 18751
# publishers
# 18751
# tags
# 18751

# %%
#write the above dataframe, with cleaned up lists for contributors, affiliations, publishers, and tags, to a new excel doc
# testing.to_excel('SHARE_cleaned_lists.xlsx', index=False)
testing.to_csv('SHARE_cleaned_lists.csv', index=False)

# %%
#and then read in this document to analyze
# df = pd.read_excel('SHARE_cleaned_lists.xlsx', index=False)
df = pd.read_csv('SHARE_cleaned_lists.csv')

# %%
df.head()
# Out:
#              _id             _index  _score          _type             sort  \
# 0  46243-B78-8F9  share_customtax_1     NaN  creativeworks  [1505096181545]
# 1  460D5-0F1-870  share_customtax_1     NaN  creativeworks  [1505096180930]
# 2  46065-8A1-338  share_customtax_1     NaN  creativeworks  [1505009985066]
# 3  460C4-C4F-337  share_customtax_1     NaN  creativeworks  [1505009809752]
# 4  461F6-6B8-F85  share_customtax_1     NaN  creativeworks  [1505009201018]
#
#                                         affiliations  \
# 0  ['MPIK/CERN', 'Chalmers University of Technolo...
# 1  ['MPIK/CERN', 'Chalmers University of Technolo...
# 2  ['University of California at San Diego (Unite...
# 3       ['University of California (United States)']
# 4  ['Department of Philosophy', 'University of Ca...
#
#                                         contributors  \
# 0  ['Dario Berzano', 'Guilherme Amadio', 'Pere Ma...
# 1  ['Dario Berzano', 'Guilherme Amadio', 'Pere Ma...
# 2  ['S. C. Esener', 'M. A. Title', 'S. H. Lee', '...
# 3  ['R. C. Puetter', 'Scott D. Friedman', 'Barbar...
# 4                              ['Donald Rutherford']
#
#                          date                      date_created  \
# 0  2017-08-25 00:00:00.000000  2017-09-11T02:16:21.545767+00:00
# 1  2017-08-25 00:00:00.000000  2017-09-11T02:16:20.930481+00:00
# 2  2017-09-09 19:30:32.000000  2017-09-10T02:19:45.066231+00:00
# 3  2017-09-09 13:41:12.000000  2017-09-10T02:16:49.752745+00:00
# 4  2017-09-09 06:46:18.000000  2017-09-10T02:06:41.018803+00:00
#
#                       date_modified    ...    registration_type retracted  \
# 0   2017-09-11T02:16:26.21514+00:00    ...                  NaN         0
# 1  2017-09-11T02:16:20.930452+00:00    ...                  NaN         0
# 2  2017-09-10T02:19:45.066215+00:00    ...                  NaN         0
# 3  2017-09-10T02:16:49.752713+00:00    ...                  NaN         0
# 4  2017-09-10T02:06:41.018787+00:00    ...                  NaN         0
#
#           sources subject_synonyms subjects  \
# 0  [DataCite MDS]               []       []
# 1  [DataCite MDS]               []       []
# 2      [CrossRef]               []       []
# 3      [CrossRef]               []       []
# 4      [CrossRef]               []       []
#
#                                   tags  \
# 0  ['cern.zenodo', 'cern', 'software']
# 1  ['cern', 'cern.zenodo', 'software']
# 2                                 ['']
# 3                                 ['']
# 4                    ['health policy']
#
#                                                title              type  \
# 0  Root - An Object-Oriented Data Analysis Framew...          software
# 1  Root - An Object-Oriented Data Analysis Framew...          software
# 2  One-Dimensional Silicon/PLZT Spatial Light Mod...  conference paper
# 3  The University of California at San Diego Near...  conference paper
# 4                         Nietzsche as perfectionist           article
#
#                                             types withdrawn
# 0                       [software, creative work]       NaN
# 1                       [software, creative work]       NaN
# 2  [conference paper, publication, creative work]       NaN
# 3  [conference paper, publication, creative work]       NaN
# 4           [article, publication, creative work]       NaN
#
# [5 rows x 31 columns]

# %%
"""write all affiliations into a single list to review-
leave the quotations on to make it easy to distinguish what individual values in the raw data were"""
affiliations = []
for row in df['affiliations']:
    row = row.strip("[").strip("]").strip()
    row = [str(x) for x in row.split(',')]
    for item in row:
        if item not in affiliations:
                affiliations.append(item)

# %%
"""write all contributors into a single list to review
leave the quotations on to make it easy to distinguish what individual values in the raw data were"""
contributors = []
for row in df['contributors']:
    row = row.strip("[").strip("]").strip() 
    row = [str(x) for x in row.split(',')]
    for item in row:
        if item not in contributors:
                contributors.append(item)

# %%
#write both to their own dataframe (and csv files) for lazy eval
affil = pd.DataFrame(np.array(affiliations))
affil.to_csv('affiliations_list.csv')
cont = pd.DataFrame(np.array(contributors))
cont.to_csv('contributors_list.csv')

# %%
affil.sort_values(0).head(10)
# Out:
#                                                        0
# 14070                               "3941 O'Hara Street"
# 1679    "Alberta Children's Hospital Research Institu...
# 867         "Alzheimer's Therapeutic Research Institute"
# 13888               "Anhui (People's Republic of China)"
# 11836   "Ann & Robert H. Lurie Children's Hospital of...
# 12353   "Ariadne Labs at Brigham and Women's Hospital...
# 5662            "Arizona Parkinson's Disease Consortium"
# 15580                     "Banner Alzheimer's Institute"
# 13608   "Barrow Neurological Institute at Phoenix Chi...
# 18462   "Biostatistics Core; Nationwide Children's Ho...

# %%
affil.sort_values(0).tail(10)
# Out:
#                                                        0
# 266                                     'and Metabolism'
# 12555                          'and Occupational Health'
# 1655                'and Physical Oceanography Division'
# 841                                      'and Promotion'
# 8044   'and Qingdao National Laboratory for Marine Sc...
# 18030                         'and University of Sydney'
# 11089             'and Veterans Administration Hospital'
# 1698               'and \xc2\xa7Department of Radiology'
# 2080               'and the Riley Heart Research Center'
# 11955  'the Sahlgrenska Academy at University of Goth...

# %%
cont.sort_values(0).head(10)
# Out:
#                                                        0
# 43853   "APC - Gravitation (APC-Gravitation) ; AstroP...
# 18990   "AT-TAF 2600) for their support. C. Havermans...
# 58559                                    "Aaron O'Leary"
# 30532   "Adaptation and Learning (SICAL) ; Laboratoir...
# 34108   "Algorithmic number theory for cryptology (TA...
# 19395   "Algorithmics for computationally intensive a...
# 29327   "Algorithmics for computationally intensive a...
# 33338   "Algorithms and Models for Integrative Biolog...
# 33350   "Algorithms and Models for Integrative Biolog...
# 19393   "Algorithms and Scheduling for Distributed He...

# %%
cont.sort_values(0).tail(10)
# Out:
#                                                        0
# 62208                                      'da Silveira'
# 59935                                        'de Janvry'
# 58295                                         'deFrance'
# 19963                                  'jswift@ucsd.edu'
# 55147                                        'kc claffy'
# 19962                                      're3data.org'
# 39455  'representation and transformations for image ...
# 20793                                'sroberts@ucar.edu'
# 26941                                    'von Dadelszen'
# 15670                                            'wmtan'

# %%
affil.head(20)
# Out:
#                                                     0
# 0                                         'MPIK/CERN'
# 1                 'Chalmers University of Technology'
# 2                                              'CERN'
# 3             'Johannes Gutenberg Universitaet Mainz'
# 4                                'Uppsala University'
# 5                                          'Fermilab'
# 6                                               'GSI'
# 7                                               'LBL'
# 8                              'Princeton University'
# 9                                              'UCSD'
# 10  'University of California at San Diego (United...
# 11         'University of California (United States)'
# 12                         'Department of Philosophy'
# 13                         'University of California'
# 14                                        'San Diego'
# 15  'University of California at San Diego - Depar...
# 16     'University of Iowa - Department of Pathology'
# 17   'University of Texas Southwestern Medical Cen...
# 18                    'ProPath\xc2\xae; Dallas Texas'
# 19                         'TX; and Razelle Kurzrock'
